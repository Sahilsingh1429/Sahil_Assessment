# %%
# Prepare demonstration of Python E-Note Book under software development principles and follow coding protocols

1.) Write a clear problem statement: Before starting any software development,it is essential to write a clear problem statement.
    In the case of our Python E-Notebook, the problem statement could be
    "To develop a console-based Python E-Notebook application that allows users to
    create and share documents containing live code, equations, visualizations, and narrative text."

2.) Define the scope and requirements: Once we have a clear problem statement,we need to define the scope and requirements of the application.
    This includes deciding what features the application should have,what platforms it should run on,and any performance requirements.
    We can also define any constraints,such as time or budget limitations.
    
3.) Design the architecture: Once we have defined the scope and requirements, we can design the architecture of the application.
    This involves deciding on the overall structure of the application,including the user interface,
    data storage, and any third-party libraries or services that will be used.

4.) Write the code: With the architecture designed, we can start writing the code.
    We should follow coding protocols and best practices such as writing clean, readable code, commenting our code, and using version control.
    
5.) Test the application: Once we have written the code, we need to test the application to ensure it meets the requirements and 
    functions correctly.We should also test the application in various environments to ensure it runs correctly on different platforms.
    
Some coding protocols we can follow when developing the Python E-Notebook include:
    
Following the PEP 8 style guide for Python code.
Using meaningful variable and function names.
Writing docstrings for all functions and modules.
Using comments to explain complex code or logic.
Avoiding hardcoded values and using constants instead.
Using try-except blocks to handle exceptions.
Using version control, such as Git, to track changes and collaborate with others.

# %%
# In this application 3 operations involved (generate note, view note)
#  Execution of the code following menu must be displayed.
#  Make sure each business logic is denoted with appropriate comments and
# make your code interactive and represent clean and clear output on your
# console screen.


import os

def generate_note():
    filename=input('Enter a Filename:')
    content=input('Enter a note Content:')
    
    with open(filename,'a') as file:
        file.write(content)
        
    print(f"Note '{filename}'genearated Sucessfully")
    input("Enter a Generator name:")
    input("Enter a python E-Consle Title:")
def view_note():
    filename=input("Enter Filename:")
    
    if os.path.isfile(filename):
        with open(filename,'r') as file:
            print(file.read())
            
    else:
        print(f"Note '{filename}' does not Exist")
        
while True:
    print("Welcome To Python E- Note")
    print("\nMenu:")
    print("1. Generate Note")
    print("2. View Note")
    print("3. Exit")
    
    choice = input("Enter Your Choice:")
    
    
    if choice == "1":
        generate_note()
    if choice == "2":
        view_note()
    elif choice == "3":
        print("Exit Program...!!")
        break
    else:
        print("Invalid Choice.Please Enter valid choice(1-3)..")
# Out:
# Welcome To Python E- Note
#
# Menu:
# 1. Generate Note
# 2. View Note
# 3. Exit
# Enter Your Choice:2
# Enter Filename:python.txt
# python is easy to learnpython is easy to debug\npython is to debugpython is high level languagepython is object oriented programming language
# Welcome To Python E- Note
#
# Menu:
# 1. Generate Note
# 2. View Note
# 3. Exit
# Enter Your Choice:3
# Exit Program...!!
